# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from gather_data import *

# %%
mls23_df = add_weather_info(df_from_fbref(year='current'))
mls23_df
# Out:
#                round  day        date  local_time  home_team home_score  \
# 0     Regular Season  Sat  2023-02-25        15.5         15          2
# 1     Regular Season  Sat  2023-02-25        19.5          4          2
# 2     Regular Season  Sat  2023-02-25        19.5          7          0
# 3     Regular Season  Sat  2023-02-25        19.5          0          2
# 4     Regular Season  Sat  2023-02-25        19.5         20          4
# ..               ...  ...         ...         ...        ...        ...
# 509   Regular Season  Sat  2023-10-21        19.0          5          0
# 510   Regular Season  Sat  2023-10-21        20.0         26          0
# 511   Regular Season  Sat  2023-10-21        20.0         25          3
# 512  Wild Card Round  Wed  2023-10-25        19.5         18          5
# 513  Wild Card Round  Wed  2023-10-25        20.5         25          0
#
#     away_score  away_team  attendance                     stadium  ...  \
# 0            0         17       28051                 Geodis Park  ...
# 1            1          9       25513                 TQL Stadium  ...
# 2            1         12       19096              Toyota Stadium  ...
# 3            1         23       67538       Mercedes-Benz Stadium  ...
# 4            1          6       18510                 Subaru Park  ...
# ..         ...        ...         ...                         ...  ...
# 509          1         22       17538  Dick's Sporting Goods Park  ...
# 510          2         24       22423                    Citypark  ...
# 511          1         12       20479       Children's Mercy Park  ...
# 512          2          2       16074              Red Bull Arena  ...
# 513          0         23       17437       Children's Mercy Park  ...
#
#      same_conf  rivals  temperature  rain  snow  cloudcover  windspeed  \
# 0            1       0         45.0   1.8  0.00       100.0        7.4
# 1            0       0         50.6   0.0  0.00         5.0        8.9
# 2            1       0         42.8   0.0  0.00       100.0        5.4
# 3            0       0         60.1   0.3  0.00       100.0       10.7
# 4            1       0         32.7   0.0  0.21        95.0        7.7
# ..         ...     ...          ...   ...   ...         ...        ...
# 509          1       1         75.9   0.0  0.00        18.0        8.7
# 510          1       0         74.3   0.0  0.00         0.0       22.4
# 511          1       0         76.0   0.0  0.00         0.0       14.0
# 512          1       0          NaN   NaN   NaN         NaN        NaN
# 513          1       0          NaN   NaN   NaN         NaN        NaN
#
#      windgust  rain_sum  snow_sum
# 0        30.6       4.2      0.00
# 1        25.6       0.0      0.00
# 2        13.7       4.6      0.00
# 3        21.6       6.1      0.00
# 4        20.5       0.0      0.49
# ..        ...       ...       ...
# 509      24.8       0.0      0.00
# 510      45.4       0.0      0.00
# 511      30.2       0.0      0.00
# 512       NaN       NaN       NaN
# 513       NaN       NaN       NaN
#
# [495 rows x 25 columns]

# %%
mls22_df = add_weather_info(df_from_fbref(year=2022))
mls22_df
# Out:
#                      round  day        date  local_time  home_team home_score  \
# 0           Regular Season  Sat  2022-02-26        12.5         11          3
# 1           Regular Season  Sat  2022-02-26        13.0         20          1
# 2           Regular Season  Sat  2022-02-26        15.0         23          1
# 3           Regular Season  Sat  2022-02-26        15.5          6          4
# 4           Regular Season  Sat  2022-02-26        16.5          7          1
# ..                     ...  ...         ...         ...        ...        ...
# 503  Conference Semifinals  Sun  2022-10-23        13.0         14          1
# 504  Conference Semifinals  Sun  2022-10-23        19.0          1          2
# 505      Conference Finals  Sun  2022-10-30        12.0         11          3
# 506      Conference Finals  Sun  2022-10-30        20.0         20          3
# 507                MLS Cup  Sat  2022-11-05        13.0         11          3
#
#     away_score  away_team  attendance                     stadium  ...  \
# 0            0          5       22010  Banc of California Stadium  ...
# 1            1         12       17487                 Subaru Park  ...
# 2            3         18       16146                 PayPal Park  ...
# 3            0         28       18939             Lower.com Field  ...
# 4            1         27       12233              Toyota Stadium  ...
# ..         ...        ...         ...                         ...  ...
# 503          3         17       19619                Stade Saputo  ...
# 504          1          7       20738                  Q2 Stadium  ...
# 505          0          1       22175  Banc of California Stadium  ...
# 506          1         17       19770                 Subaru Park  ...
# 507          3         20       22384  Banc of California Stadium  ...
#
#      same_conf  rivals  temperature  rain  snow  cloudcover  windspeed  \
# 0            1       0         38.1   0.0   0.0           0        7.1
# 1            0       0         29.4   0.0   0.0          74       10.2
# 2            0       0         47.0   0.0   0.0          30        9.4
# 3            0       0         29.5   0.0   0.0          91        8.8
# 4            0       0         33.0   0.0   0.0         100        9.7
# ..         ...     ...          ...   ...   ...         ...        ...
# 503          1       0         48.5   0.0   0.0           1        8.4
# 504          1       1         82.8   0.0   0.0          62       28.2
# 505          1       0         53.3   0.0   0.0          32        5.8
# 506          1       0         62.1   0.0   0.0          27        4.3
# 507          0       0         49.3   0.0   0.0           4        3.9
#
#      windgust  rain_sum  snow_sum
# 0        14.4       0.0       0.0
# 1        20.2       0.0       0.0
# 2        16.6       0.0       0.0
# 3        23.4       0.0       0.0
# 4        22.0       0.8       0.0
# ..        ...       ...       ...
# 503      13.3       0.0       0.0
# 504      55.4       0.0       0.0
# 505      11.9       0.0       0.0
# 506      13.0       0.0       0.0
# 507      10.4       0.0       0.0
#
# [489 rows x 25 columns]

# %%
mls21_df = add_weather_info(df_from_fbref(year=2021))
mls21_df
# Out:
#                      round  day        date  local_time  home_team home_score  \
# 0           Regular Season  Sat  2021-04-17        14.0         14          4
# 1           Regular Season  Sat  2021-04-17        15.0         11          2
# 2           Regular Season  Sat  2021-04-17        15.0         19          0
# 3           Regular Season  Fri  2021-04-16        18.5         24          4
# 4           Regular Season  Fri  2021-04-16        19.0          9          2
# ..                     ...  ...         ...         ...        ...        ...
# 485  Conference Semifinals  Sun  2021-11-28        17.5         20          1
# 486  Conference Semifinals  Tue  2021-11-30        19.5         16          2
# 487      Conference Finals  Sat  2021-12-04        15.5         21          2
# 488      Conference Finals  Sun  2021-12-05        15.0         20          1
# 489                MLS Cup  Sat  2021-12-11        12.0         21          1
#
#     away_score  away_team  attendance                     stadium  ...  \
# 0            2         27           0             DRV PNK Stadium  ...
# 1            0          1        4900  Banc of California Stadium  ...
# 2            0          0       11503            Exploria Stadium  ...
# 3            0         12        7042                 Lumen Field  ...
# 4            1         23        6376                BBVA Stadium  ...
# ..         ...        ...         ...                         ...  ...
# 485          1         15       19076                 Subaru Park  ...
# 486          2         17       25509            Gillette Stadium  ...
# 487          0         22       25218             Providence Park  ...
# 488          2         17       19487                 Subaru Park  ...
# 489          1         17       25218             Providence Park  ...
#
#      same_conf  rivals  temperature  rain  snow  cloudcover  windspeed  \
# 0            1       1         79.8   0.0   0.0          30       11.1
# 1            1       0         55.2   0.0   0.0          50        5.1
# 2            1       0         77.8   0.0   0.0         100        9.8
# 3            1       0         66.2   0.0   0.0           0        6.5
# 4            1       0         71.6   0.4   0.0         100       12.2
# ..         ...     ...          ...   ...   ...         ...        ...
# 485          1       0         47.6   0.0   0.0           8        6.6
# 486          1       0         38.2   0.0   0.0          88       12.2
# 487          1       0         36.8   0.0   0.0          76        8.3
# 488          1       0         44.0   0.0   0.0          11        4.5
# 489          0       0         43.0   2.8   0.0         100       27.6
#
#      windgust  rain_sum  snow_sum
# 0        30.6       0.0      0.00
# 1        11.5       0.0      0.00
# 2        38.5       0.0      0.00
# 3        14.8       0.0      0.00
# 4        36.4       0.4      0.00
# ..        ...       ...       ...
# 485      25.9       0.0      0.07
# 486      29.5       0.0      0.00
# 487      15.8       0.0      0.00
# 488      16.2       0.0      0.00
# 489      61.2       9.7      0.00
#
# [472 rows x 25 columns]

# %%
mls19_df = add_weather_info(df_from_fbref(year=2019))
mls19_df
# Out:
#                      round  day        date  local_time  home_team home_score  \
# 0           Regular Season  Sat  2019-03-02        13.0         20          1
# 1           Regular Season  Sat  2019-03-02        14.5         19          2
# 2           Regular Season  Sat  2019-03-02        15.0         28          2
# 3           Regular Season  Sat  2019-03-02        15.5          7          1
# 4           Regular Season  Sat  2019-03-02        16.0          5          3
# ..                     ...  ...         ...         ...        ...        ...
# 432  Conference Semifinals  Thu  2019-10-24        19.5         11          5
# 433  Conference Semifinals  Thu  2019-10-24        20.0          0          2
# 434      Conference Finals  Tue  2019-10-29        19.0         11          1
# 435      Conference Finals  Wed  2019-10-30        20.0          0          1
# 436           MLS Cup 2019  Sun  2019-11-10        15.0         24          3
#
#     away_score  away_team  attendance                     stadium  ...  \
# 0            3         27       16498        Talen Energy Stadium  ...
# 1            2         17       25527        Orlando City Stadium  ...
# 2            3         12       27837            BC Place Stadium  ...
# 3            1         16       14327              Toyota Stadium  ...
# 4            3         21       12717  Dick's Sporting Goods Park  ...
# ..         ...        ...         ...                         ...  ...
# 432          3         10       22902  Banc of California Stadium  ...
# 433          0         20       41507       Mercedes-Benz Stadium  ...
# 434          3         24       22099  Banc of California Stadium  ...
# 435          2         27       44055       Mercedes-Benz Stadium  ...
# 436          1         27       69274           CenturyLink Field  ...
#
#      same_conf  rivals  temperature  rain  snow  cloudcover  windspeed  \
# 0            1       0         32.6   0.0  0.00         100        9.4
# 1            1       0         68.5   0.0  0.00          31        6.2
# 2            1       0         30.9   0.0  0.00           1       15.1
# 3            0       0         40.1   0.0  0.00         100       10.4
# 4            1       0         25.6   0.0  0.21          88       14.5
# ..         ...     ...          ...   ...   ...         ...        ...
# 432          1       1         92.8   0.0  0.00           0       12.6
# 433          1       0         68.2   0.0  0.00          40       10.9
# 434          1       0         68.8   0.0  0.00          10       11.2
# 435          1       0         68.2   1.0  0.00         100       19.2
# 436          0       0         48.7   0.0  0.00         100        2.3
#
#      windgust  rain_sum  snow_sum
# 0        21.2      10.9      0.49
# 1        14.8       0.0      0.00
# 2        24.8       0.0      0.00
# 3        24.1       0.0      0.00
# 4        27.0       0.1      2.24
# ..        ...       ...       ...
# 432      27.4       0.0      0.00
# 433      24.5       0.0      0.00
# 434      27.0       0.0      0.00
# 435      43.2      11.9      0.00
# 436       3.6       1.1      0.00
#
# [421 rows x 25 columns]

# %%
mls18_df = add_weather_info(df_from_fbref(year=2018))
mls18_df
# Out:
#                  round  day        date  local_time  home_team home_score  \
# 0       Regular Season  Sat  2018-03-03        13.0         27          0
# 1       Regular Season  Sat  2018-03-03        14.5          9          4
# 2       Regular Season  Sun  2018-03-04        14.0         24          0
# 3       Regular Season  Sun  2018-03-04        15.0         28          2
# 4       Regular Season  Sat  2018-03-03        19.0         20          2
# ..                 ...  ...         ...         ...        ...        ...
# 419  Conference Finals  Sun  2018-11-25        17.0          0          3
# 420  Conference Finals  Sun  2018-11-25        16.5         21          0
# 421  Conference Finals  Thu  2018-11-29        19.5         18          1
# 422  Conference Finals  Thu  2018-11-29        20.5         25          2
# 423       MLS Cup 2018  Sat  2018-12-08        20.0          0          2
#
#     away_score  away_team  attendance                stadium  ...  same_conf  \
# 0            2          6       26633              BMO Field  ...          1
# 1            0          0       20377   BBVA Compass Stadium  ...          0
# 2            1         11       40070      CenturyLink Field  ...          1
# 3            1         14       27837               BC Place  ...          0
# 4            0         16       16452   Talen Energy Stadium  ...          1
# ..         ...        ...         ...                    ...  ...        ...
# 419          0         18       70016  Mercedes-Benz Stadium  ...          1
# 420          0         25       21144        Providence Park  ...          1
# 421          0          0       22137         Red Bull Arena  ...          1
# 422          3         21       20091  Children's Mercy Park  ...          1
# 423          0         21       73019  Mercedes-Benz Stadium  ...          0
#
#      rivals  temperature  rain  snow  cloudcover  windspeed  windgust  \
# 0         1         27.8   0.0   0.0           1       21.6      42.5
# 1         0         55.8   0.0   0.0          40       13.6      23.4
# 2         0         30.0   0.0   0.0          27        7.2      18.0
# 3         0         32.6   0.0   0.0          65        7.6      15.5
# 4         0         44.3   0.0   0.0          14       27.3      61.9
# ..      ...          ...   ...   ...         ...        ...       ...
# 419       0         52.4   0.0   0.0          11        7.6      20.5
# 420       0         33.7   0.0   0.0          28        2.3       9.7
# 421       0         44.8   0.0   0.0          88       21.3      44.6
# 422       0         39.2   0.0   0.0           0        6.2      16.6
# 423       0         39.6   1.6   0.0         100       17.5      33.8
#
#      rain_sum  snow_sum
# 0         0.0      0.00
# 1         0.0      0.00
# 2         0.0      0.00
# 3         0.0      0.00
# 4         0.0      0.91
# ..        ...       ...
# 419       0.0      0.00
# 420       0.0      0.00
# 421       0.0      0.00
# 422       0.0      0.00
# 423      15.5      0.00
#
# [408 rows x 25 columns]

# %%
mlsall_df = pd.concat([mls18_df, mls19_df, mls21_df, mls22_df, mls23_df], axis=0)
mlsall_df['date_year'] = mlsall_df['date'].apply(lambda x: int(x[0:4]))
mlsall_df['date_month'] = mlsall_df['date'].apply(lambda x: int(x[5:7]))
mlsall_df['date_day'] = mlsall_df['date'].apply(lambda x: int(x[8:10]))
mlsall_df.reset_index(drop=True, inplace=True)
mlsall_df
# Out:
#                 round  day        date  local_time  home_team home_score  \
# 0      Regular Season  Sat  2018-03-03        13.0         27          0
# 1      Regular Season  Sat  2018-03-03        14.5          9          4
# 2      Regular Season  Sun  2018-03-04        14.0         24          0
# 3      Regular Season  Sun  2018-03-04        15.0         28          2
# 4      Regular Season  Sat  2018-03-03        19.0         20          2
# ...               ...  ...         ...         ...        ...        ...
# 2280   Regular Season  Sat  2023-10-21        19.0          5          0
# 2281   Regular Season  Sat  2023-10-21        20.0         26          0
# 2282   Regular Season  Sat  2023-10-21        20.0         25          3
# 2283  Wild Card Round  Wed  2023-10-25        19.5         18          5
# 2284  Wild Card Round  Wed  2023-10-25        20.5         25          0
#
#      away_score  away_team  attendance                     stadium  ...  rain  \
# 0             2          6       26633                   BMO Field  ...   0.0
# 1             0          0       20377        BBVA Compass Stadium  ...   0.0
# 2             1         11       40070           CenturyLink Field  ...   0.0
# 3             1         14       27837                    BC Place  ...   0.0
# 4             0         16       16452        Talen Energy Stadium  ...   0.0
# ...         ...        ...         ...                         ...  ...   ...
# 2280          1         22       17538  Dick's Sporting Goods Park  ...   0.0
# 2281          2         24       22423                    Citypark  ...   0.0
# 2282          1         12       20479       Children's Mercy Park  ...   0.0
# 2283          2          2       16074              Red Bull Arena  ...   NaN
# 2284          0         23       17437       Children's Mercy Park  ...   NaN
#
#       snow  cloudcover  windspeed  windgust  rain_sum  snow_sum  date_year  \
# 0      0.0         1.0       21.6      42.5       0.0      0.00       2018
# 1      0.0        40.0       13.6      23.4       0.0      0.00       2018
# 2      0.0        27.0        7.2      18.0       0.0      0.00       2018
# 3      0.0        65.0        7.6      15.5       0.0      0.00       2018
# 4      0.0        14.0       27.3      61.9       0.0      0.91       2018
# ...    ...         ...        ...       ...       ...       ...        ...
# 2280   0.0        18.0        8.7      24.8       0.0      0.00       2023
# 2281   0.0         0.0       22.4      45.4       0.0      0.00       2023
# 2282   0.0         0.0       14.0      30.2       0.0      0.00       2023
# 2283   NaN         NaN        NaN       NaN       NaN       NaN       2023
# 2284   NaN         NaN        NaN       NaN       NaN       NaN       2023
#
#       date_month  date_day
# 0              3         3
# 1              3         3
# 2              3         4
# 3              3         4
# 4              3         3
# ...          ...       ...
# 2280          10        21
# 2281          10        21
# 2282          10        21
# 2283          10        25
# 2284          10        25
#
# [2285 rows x 28 columns]

# %%
mlsall_df.to_csv('mls_with_weather.csv')

# %%
conf_riv_df = pd.read_excel('mls_rivals.xlsx', sheet_name='2023')
conf_riv_df
# Out:
#                       Team  Team_ID Conference      Rivals
# 0           Atlanta United        0          E          []
# 1                Austin FC        1          W       [7,9]
# 2             Charlotte FC        2          E          []
# 3             Chicago Fire        3          E         [7]
# 4            FC Cincinnati        4          E         [6]
# 5          Colorado Rapids        5          W        [22]
# 6            Columbus Crew        6          E      [4,27]
# 7                FC Dallas        7          W     [1,3,9]
# 8              D.C. United        8          E        [18]
# 9           Houston Dynamo        9          W       [1,7]
# 10      Los Angeles Galaxy       10          W     [11,23]
# 11          Los Angeles FC       11          W        [10]
# 12        Minnesota United       12          W          []
# 13             Inter Miami       13          E        [19]
# 14             CF Montréal       14          E        [27]
# 15            Nashville SC       15          E          []
# 16  New England Revolution       16          E          []
# 17        New York City FC       17          E        [18]
# 18      New York Red Bulls       18          E      [8,17]
# 19            Orlando City       19          E        [13]
# 20      Philadelphia Union       20          E          []
# 21        Portland Timbers       21          W     [24,28]
# 22          Real Salt Lake       22          W         [5]
# 23    San Jose Earthquakes       23          W     [10,24]
# 24        Seattle Sounders       24          W  [21,23,28]
# 25    Sporting Kansas City       25          W        [26]
# 26            St. Louis FC       26          W        [25]
# 27              Toronto FC       27          E      [6,14]
# 28     Vancouver Whitecaps       28          W     [21,24]

# %%
conf_riv_df['Rivals'] = conf_riv_df.Rivals.apply(eval)

# %%
conf_riv_df[conf_riv_df['Team_ID']==1]['Conference'].iloc[0] == conf_riv_df[conf_riv_df['Team_ID']==5]['Conference'].iloc[0]
# Out:
# True

# %%
[conf_riv_df[conf_riv_df['Team_ID']==x]['Conference'].iloc[0] for x in mlsall_df['home_team']]
# Out:
# ['E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'W',
#  'W',
#  'E',
#  'W',
#  'W',
#  'W',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'E',
#  'W',
#  'W',
#  'W',
#  'W',
#  ...]

# %%
conf_riv_df[conf_riv_df['Team_ID']==1]['Rivals'].iloc[0]
# Out:
# [7, 9]

# %%
[conf_riv_df[conf_riv_df['Team_ID']==x]['Conference'].iloc[0] for x in mlsall_df['home_team']]

# %%
mlsall_df = pd.read_csv('mls_with_weather.csv', index_col=0)
mlsall_df
# Out:
#                 round  day        date  local_time  home_team  home_score  \
# 0      Regular Season  Sat  2018-03-03        13.0         27           0
# 1      Regular Season  Sat  2018-03-03        14.5          9           4
# 2      Regular Season  Sun  2018-03-04        14.0         24           0
# 3      Regular Season  Sun  2018-03-04        15.0         28           2
# 4      Regular Season  Sat  2018-03-03        19.0         20           2
# ...               ...  ...         ...         ...        ...         ...
# 2280   Regular Season  Sat  2023-10-21        19.0          5           0
# 2281   Regular Season  Sat  2023-10-21        20.0         26           0
# 2282   Regular Season  Sat  2023-10-21        20.0         25           3
# 2283  Wild Card Round  Wed  2023-10-25        19.5         18           5
# 2284  Wild Card Round  Wed  2023-10-25        20.5         25           0
#
#       away_score  away_team  attendance                     stadium  ...  \
# 0              2          6       26633                   BMO Field  ...
# 1              0          0       20377        BBVA Compass Stadium  ...
# 2              1         11       40070           CenturyLink Field  ...
# 3              1         14       27837                    BC Place  ...
# 4              0         16       16452        Talen Energy Stadium  ...
# ...          ...        ...         ...                         ...  ...
# 2280           1         22       17538  Dick's Sporting Goods Park  ...
# 2281           2         24       22423                    Citypark  ...
# 2282           1         12       20479       Children's Mercy Park  ...
# 2283           2          2       16074              Red Bull Arena  ...
# 2284           0         23       17437       Children's Mercy Park  ...
#
#       rain  snow  cloudcover  windspeed  windgust  rain_sum  snow_sum  \
# 0      0.0   0.0         1.0       21.6      42.5       0.0      0.00
# 1      0.0   0.0        40.0       13.6      23.4       0.0      0.00
# 2      0.0   0.0        27.0        7.2      18.0       0.0      0.00
# 3      0.0   0.0        65.0        7.6      15.5       0.0      0.00
# 4      0.0   0.0        14.0       27.3      61.9       0.0      0.91
# ...    ...   ...         ...        ...       ...       ...       ...
# 2280   NaN   NaN         NaN        NaN       NaN       NaN       NaN
# 2281   NaN   NaN         NaN        NaN       NaN       NaN       NaN
# 2282   NaN   NaN         NaN        NaN       NaN       NaN       NaN
# 2283   NaN   NaN         NaN        NaN       NaN       NaN       NaN
# 2284   NaN   NaN         NaN        NaN       NaN       NaN       NaN
#
#       date_year  date_month  date_day
# 0          2018           3         3
# 1          2018           3         3
# 2          2018           3         4
# 3          2018           3         4
# 4          2018           3         3
# ...         ...         ...       ...
# 2280       2023          10        21
# 2281       2023          10        21
# 2282       2023          10        21
# 2283       2023          10        25
# 2284       2023          10        25
#
# [2285 rows x 25 columns]
